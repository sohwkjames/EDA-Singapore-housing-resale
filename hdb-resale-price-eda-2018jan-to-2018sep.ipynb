# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot
import seaborn as sns

# %%
df = pd.read_csv("gov-housing/resale-housing-prices-2018jan-to-2018sep.csv")

# %%
# Out:
#          month        town         flat_type block        street_name  \
# 0      2018-01  ANG MO KIO            2 ROOM   314   ANG MO KIO AVE 3
# 1      2018-01  ANG MO KIO            3 ROOM   319   ANG MO KIO AVE 1
# 2      2018-01  ANG MO KIO            3 ROOM   319   ANG MO KIO AVE 1
# 3      2018-01  ANG MO KIO            3 ROOM   333   ANG MO KIO AVE 1
# 4      2018-01  ANG MO KIO            3 ROOM   333   ANG MO KIO AVE 1
# 5      2018-01  ANG MO KIO            3 ROOM   405  ANG MO KIO AVE 10
# 6      2018-01  ANG MO KIO            3 ROOM   560  ANG MO KIO AVE 10
# 7      2018-01  ANG MO KIO            3 ROOM   576  ANG MO KIO AVE 10
# 8      2018-01  ANG MO KIO            3 ROOM   443  ANG MO KIO AVE 10
# 9      2018-01  ANG MO KIO            3 ROOM   466  ANG MO KIO AVE 10
# 10     2018-01  ANG MO KIO            3 ROOM   440  ANG MO KIO AVE 10
# 11     2018-01  ANG MO KIO            3 ROOM   557  ANG MO KIO AVE 10
# ...
